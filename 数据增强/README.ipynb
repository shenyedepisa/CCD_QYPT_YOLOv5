# %% [markdown]
# ## 数据处理
#
# 若想生成文字图片、图像加噪声、图像模糊处理、绘制标注框、转灰度图片等代码，以供参考

# %% [markdown]
# ## 图片加噪声，模糊处理
#
# `addnoisy.py`, `blur.py`, `drawlabel`, `rgb2gray.py` 都是对图片进行加工，可以参考以下操作

# %%
# !python addnoisy.py --src ./data-non/images --dst ./data-non/images_noise
# Out:
# ./data-non/images
# ./data-non/images_noise
# ./data-non/images_noise/image_000001.jpg done
# ./data-non/images_noise/image_000002.jpg done
# ./data-non/images_noise/image_000003.jpg done
# ./data-non/images_noise/image_000004.jpg done
# ./data-non/images_noise/image_000005.jpg done
# ./data-non/images_noise/image_000006.jpg done
# ./data-non/images_noise/image_000007.jpg done
# ./data-non/images_noise/image_000008.jpg done
# ./data-non/images_noise/image_000009.jpg done
# ./data-non/images_noise/image_000010.jpg done
# ./data-non/images_noise/image_000011.jpg done
# ./data-non/images_noise/image_000012.jpg done
# ./data-non/images_noise/image_000013.jpg done
# ./data-non/images_noise/image_000014.jpg done
# ./data-non/images_noise/image_000015.jpg done
# ./data-non/images_noise/image_000016.jpg done
# ./data-non/images_noise/image_000017.jpg done
# ./data-non/images_noise/image_000018.jpg done
# ./data-non/images_noise/image_000019.jpg done
# ...

# %% [markdown]
# ## 加 "密" 图片
# `generateblur.py`, `generateocr.py`, `generateocr2.py`, `generateocr3.py` 都是加"密"程序，可以参考以下操作

# %%
# !python generateblur.py --src data-non/images --dst data-non/images_gb
# Out:
# data-non/images
# data-non/images_gb
# data-non/images/image_000001.jpg 424 600
# data-non/images_gb/image_000001.jpg
# data-non/images/image_000002.jpg 900 1057
# data-non/images_gb/image_000002.jpg
# data-non/images/image_000003.jpg 900 1159
# data-non/images_gb/image_000003.jpg
# data-non/images/image_000004.jpg 900 572
# data-non/images_gb/image_000004.jpg
# data-non/images/image_000005.jpg 487 600
# data-non/images_gb/image_000005.jpg
# data-non/images/image_000006.jpg 559 800
# data-non/images_gb/image_000006.jpg
# data-non/images/image_000007.jpg 800 650
# data-non/images_gb/image_000007.jpg
# data-non/images/image_000008.jpg 656 903
# data-non/images_gb/image_000008.jpg
# data-non/images/image_000009.jpg 638 903
# data-non/images_gb/image_000009.jpg
# data-non/images/image_000010.jpg 485 698
# data-non/images_gb/image_000010.jpg
# data-non/images/image_000011.jpg 1654 2339
# data-non/images_gb/image_000011.jpg
# data-non/images/image_000012.jpg 2480 3508
# ...
